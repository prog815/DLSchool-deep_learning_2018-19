# %% [markdown]
# <a href="https://colab.research.google.com/github/prog815/DLSchool-deep_learning_2018-19/blob/master/02_%5Bhomework%5Dnumpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p style="align: center;"><img align=center src="https://s8.hostingkartinok.com/uploads/images/2018/08/308b49fcfbc619d629fe4604bceb67ac.jpg" width=500 height=450/></p>
#
# <h3 style="text-align: center;"><b>Физтех-Школа Прикладной математики и информатики (ФПМИ) МФТИ</b></h3>

# %% [markdown]
# ---

# %% [markdown]
# ## Домашнее задание 2: библиотека Numpy и линейная алгебра

# %% [markdown]
# Импортируем библиотеки:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy import ndimage  # спецификатор для работы с изображениями
from scipy import misc
import scipy.stats as sps

from PIL import Image

# %matplotlib inline

# %% [markdown]
# *Вопросы для самопроверки:*
# 1. Что такое NumPy?
# 2. Зачем используется и почему работает быстрее?
# 3. Что такое линейная алгебра?
# 4. Как она связана с машинным обучением и глубоким обучением?

# %% [markdown]
# ### Задание 1

# %% [markdown]
# В первой задаче вам предлагается перемножить две квадратные матрицы двумя способами -- без использования пакета numpy и с ним.

# %%
# Для генерации матриц используем фукнцию random -- она используется для генерации случайных объектов 
# функция sample создает случайную выборку. В качестве аргумента ей передается кортеж (i,j), здесь i -- число строк,
# j -- число столбцов.
a = np.random.sample((10,10))
b = np.random.sample((10,10))
# выведите размерность (ранг) каждой матрицы с помощью функции ndim.
print(a.ndim)
print(b.ndim)
# Используйте функцию shape, что она вывела?
print(a.shape)
print(b.shape)
# ========
# тут можно писать код 

# ========
print(a)
print(b)
# Out:
# 2
# 2
# (10, 10)
# (10, 10)
# [[0.45634353 0.49069898 0.78621887 0.7804085  0.31489393 0.8103492
#   0.93292695 0.97328034 0.91539059 0.96218134]
#  [0.07637067 0.53817374 0.74771945 0.66563568 0.76237916 0.55784768
#   0.66745293 0.12375566 0.95986542 0.13187742]
#  [0.00676995 0.95177261 0.8638961  0.16088296 0.99754257 0.42186755
#   0.21980042 0.84992652 0.37543192 0.80950841]
#  [0.21881061 0.15819337 0.29922174 0.45956152 0.09936974 0.12640435
#   0.9322323  0.43330467 0.17506226 0.2371205 ]
#  [0.73333781 0.84356934 0.18924738 0.88353504 0.08121251 0.79105963
#   0.39486606 0.60719848 0.97127879 0.67695303]
#  [0.41413258 0.61347675 0.10293914 0.12379126 0.99470901 0.38122727
#   0.59757241 0.64553699 0.35955749 0.81191522]
#  [0.93984348 0.40152596 0.62703179 0.76480263 0.28724942 0.2435087
#   0.85733891 0.2057481  0.88215865 0.67684731]
#  [0.39669365 0.33905952 0.49113465 0.35122787 0.72257004 0.88491678
#   0.5684349  0.64369194 0.74874446 0.28440547]
#  [0.83704866 0.47290002 0.18234109 0.3378876  0.81474873 0.08768643
#   0.43446254 0.54192094 0.14545341 0.26431043]
#  [0.22476821 0.33565402 0.68233805 0.66263141 0.4188917  0.45386816
#   0.30499752 0.91235149 0.29905014 0.80306808]]
# [[0.64127949 0.16694747 0.39251302 0.84890983 0.20991077 0.29938655
#   0.72463441 0.43504273 0.1172908  0.0357258 ]
#  [0.33026121 0.41588994 0.21091692 0.94580347 0.33832455 0.53844166
#   0.19458812 0.23392445 0.27967759 0.82735893]
#  [0.24075453 0.12727505 0.75360067 0.14134086 0.53003729 0.59734364
#   0.66431755 0.07605586 0.36742491 0.8411819 ]
#  [0.51671115 0.29008471 0.68549985 0.56029296 0.18319661 0.52423872
#   0.8848472  0.35009399 0.78501115 0.55700031]
#  [0.72259764 0.44257888 0.74236431 0.94604144 0.5346871  0.39187003
#   0.34201949 0.14168653 0.90160769 0.49679203]
#  [0.9039124  0.92411874 0.9895305  0.46285386 0.34414667 0.71987426
#   0.67884985 0.5525974  0.56772517 0.49988434]
#  [0.2309032  0.24394256 0.5622503  0.91667775 0.71406346 0.78994141
#   0.8528225  0.81123941 0.16497931 0.56270829]
#  [0.72064774 0.29870395 0.92510981 0.56236842 0.30095081 0.32752911
#   0.4058703  0.36885874 0.46076786 0.23966209]
#  [0.07147929 0.11099603 0.6687845  0.47286525 0.55775854 0.86924723
#   0.29906451 0.29839172 0.64710352 0.11278382]
#  [0.04202898 0.86523545 0.61850383 0.34950367 0.04503091 0.32732749
#   0.75016448 0.3642676  0.88626782 0.06461218]]

# %%
def mult(a, b):
    # здесь напишите перемножение матриц без 
    # использования NumPy и выведите результат 
    # pass
    
    res = np.zeros((a.shape[0],b.shape[1]))
    
    for i in range(res.shape[0]):
        for k in range(res.shape[1]):
            for n in range(a.shape[1]):
                res[i][k] += a[i][n] * b[n][k]
                
    return res

# %%
def np_mult(a, b):
    # здесь напишите перемножение матриц с
    # использованием NumPy и выведите результат
    
    #pass
    
    return np.dot(a,b)

# %%
# %%time
# засечем время работы функции без NumPy
mult(a,b)
# Out:
# CPU times: user 1.94 ms, sys: 0 ns, total: 1.94 ms
# Wall time: 1.97 ms
# array([[3.02993948, 2.94735845, 5.07795526, 4.24453531, 2.78172251,
#         4.1527305 , 4.48301475, 2.87820792, 3.88370738, 3.00347995],
#        [2.12326433, 1.79819086, 3.49450482, 3.21333108, 2.37114533,
#         3.25388044, 2.89065445, 1.78687108, 2.86595555, 2.62734082],
#        [2.43605381, 2.43451387, 3.78433628, 3.3970748 , 2.14794772,
#         2.85280603, 2.78588477, 1.62079492, 3.23785818, 2.73248666],
#        [1.23812096, 1.01594495, 2.0473654 , 2.05155511, 1.34327019,
#         1.80839749, 2.11568465, 1.45447887, 1.3788531 , 1.42241596],
#        [2.6513299 , 2.49185241, 3.90912775, 3.78446648, 2.05408748,
#         3.42794453, 3.54934685, 2.36943765, 3.18078846, 2.33223932],
#        [2.28331117, 2.24683026, 3.24586844, 3.49778752, 1.89286806,
#         2.50671158, 2.6846249 , 1.85237197, 2.8166942 , 1.94661762],
#        [2.14686736, 1.93186724, 3.58558141, 3.63451707, 2.23960511,
#         3.29392817, 3.70224164, 2.27468418, 2.85749205, 2.25862278],
#        [2.6487122 , 2.16932003, 3.84191221, 3.35333669, 2.24357976,
#         3.10281017, 3.02164914, 2.02917763, 2.87834015, 2.28174072],
#        [2.09180728, 1.41195761, 2.49530524, 3.04848837, 1.52641468,
#         1.90732893, 2.28911744, 1.46285678, 1.99679569, 1.61917761],
#        [2.25764195, 2.13596537, 3.59976139, 2.79709194, 1.71929206,
#         2.55643573, 3.04145677, 1.73605881, 2.90241788, 2.13967303]])

# %%
# %%time
# засечем время работы функции с NumPy
np_mult(a,b)
# Out:
# CPU times: user 767 µs, sys: 139 µs, total: 906 µs
# Wall time: 4.47 ms
# array([[3.02993948, 2.94735845, 5.07795526, 4.24453531, 2.78172251,
#         4.1527305 , 4.48301475, 2.87820792, 3.88370738, 3.00347995],
#        [2.12326433, 1.79819086, 3.49450482, 3.21333108, 2.37114533,
#         3.25388044, 2.89065445, 1.78687108, 2.86595555, 2.62734082],
#        [2.43605381, 2.43451387, 3.78433628, 3.3970748 , 2.14794772,
#         2.85280603, 2.78588477, 1.62079492, 3.23785818, 2.73248666],
#        [1.23812096, 1.01594495, 2.0473654 , 2.05155511, 1.34327019,
#         1.80839749, 2.11568465, 1.45447887, 1.3788531 , 1.42241596],
#        [2.6513299 , 2.49185241, 3.90912775, 3.78446648, 2.05408748,
#         3.42794453, 3.54934685, 2.36943765, 3.18078846, 2.33223932],
#        [2.28331117, 2.24683026, 3.24586844, 3.49778752, 1.89286806,
#         2.50671158, 2.6846249 , 1.85237197, 2.8166942 , 1.94661762],
#        [2.14686736, 1.93186724, 3.58558141, 3.63451707, 2.23960511,
#         3.29392817, 3.70224164, 2.27468418, 2.85749205, 2.25862278],
#        [2.6487122 , 2.16932003, 3.84191221, 3.35333669, 2.24357976,
#         3.10281017, 3.02164914, 2.02917763, 2.87834015, 2.28174072],
#        [2.09180728, 1.41195761, 2.49530524, 3.04848837, 1.52641468,
#         1.90732893, 2.28911744, 1.46285678, 1.99679569, 1.61917761],
#        [2.25764195, 2.13596537, 3.59976139, 2.79709194, 1.71929206,
#         2.55643573, 3.04145677, 1.73605881, 2.90241788, 2.13967303]])

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Напишите функцию, которая по данной последовательности $\{A_i\}_{i=1}^n$ строит последовательность $S_n$, где $S_k = \frac{A_1 + ... + A_k}{k}$.
# Аналогично -- с помощью библиотеки NumPy и без нее. Сравните скорость, объясните результат.

# %%
# функция, решающая задачу с помощью NumPy
def sec_av(A):
    # Ваш код здесь
    # pass
    
    B = np.array(A)
    
    return [B[k].mean() for k in range(B.shape[0])]

# %%
# функция без NumPy
def stupid_sec_av(A):
    S = [0 for i in range(len(A))]
    for i in range(len(A)):
        # Ваш код здесь
    for i in range(len(A)):
        # Ваш код здесь
    return S

# зададим некоторую последовательность и проверим ее на ваших функциях. 
# Первая функция должна работать ~ в 50 раз быстрее
A = sps.uniform.rvs(size=10 ** 7) 

# %time S1 = sec_av(A)
# %time S2 = stupid_sec_av(A)
#проверим корректность:
np.abs(S1 - S2).sum()
# Out:
#   File "<ipython-input-8-9b4cde5a41b9>", line 5
#     for i in range(len(A)):
#       ^
# IndentationError: expected an indented block

# %% [markdown]
# ### Задание 3

# %% [markdown]
# Пусть задан некоторый массив $X$. Надо построить новый массив, где все элементы с нечетными индексами требуется заменить на число $a$ (если оно не указано, то на 1). Все четные элементы исходного массива нужно возвести в куб и записать в обратном порядке относительно позиций этих элементов. Массив $X$ при этом должен остаться без изменений. В конце требуется слить массив $X$ с преобразованным $X$ и вывести в обратном порядке.

# %%
# функция, решающая задачу с помощью NumPy
def transformation(X, a=1):
    # Ваш код здесь
    
    Y = np.array(X)
    Y[1::2] = a
    
    return list(Y)

transformation(list(range(10)))
# Out:
# [0, 1, 2, 1, 4, 1, 6, 1, 8, 1]

# %%
# функция, решающая задачу  без NumPy
def stupid_transformation(X,a=1):
    # Ваш код здесь
    Y = [a if n%2==1 else elem for n,elem in enumerate(X)]
    
    return Y
    
stupid_transformation(list(range(5)))
# Out:
# [0, 1, 2, 1, 4]

# %%
X = sps.uniform.rvs(size=10 ** 7) 
# здесь код эффективнее примерно в 20 раз. 
# если Вы вдруг соберетесь печатать массив без np -- лучше сначала посмотрите на его размер
# %time S1 = transformation(X)
# %time S2 = stupid_transformation(X)
# проверим корректность:
np.abs(S1 - S2).sum()
# Out:
# CPU times: user 374 ms, sys: 382 ms, total: 756 ms
# Wall time: 755 ms
# CPU times: user 1.43 s, sys: 278 ms, total: 1.71 s
# Wall time: 1.71 s
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-8f9c7a89c4de> in <module>()
#       5 get_ipython().magic('time S2 = stupid_transformation(X)')
#       6 # проверим корректность:
# ----> 7 np.abs(S1 - S2).sum()
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %% [markdown]
# Что вы можете сказать о скорости вычислений в `NumPy`? Ответ обоснуйте.
#
# **Ответ:**

# %% [markdown]
# ### Задание 4

# %% [markdown]
# Вам подаются на вход два вектора `a` и `b` в трехмерном пространстве.Заполните их случайными числами. Реализуйте их скалярное произведение с помощью  `NumPy` и без. Засеките время работы, как это показано в заданиях выше.

# %%
a = list(np.random.sample(3)) #тут ваш код
b = list(np.random.sample(3)) #тут ваш код

# %%
def stupid_scalar_product(a,b):
    #тут ваш код
    return sum([n1*n2 for (n1,n2) in zip(a,b)])
    
stupid_scalar_product(a,b)
# Out:
# 0.46071205819138195

# %%
def numpy_scalar_product(a,b):
    #тут ваш код
    return np.dot(a,b)
    
numpy_scalar_product(a,b)
# Out:
# 0.46071205819138195

# %%
# %time product_1 = stupid_scalar_product(a,b)
# %time product_2 = numpy_scalar_product(a,b)
# проверим корректность:
np.abs(product_1 - product_2).sum()
# Out:
# CPU times: user 20 µs, sys: 7 µs, total: 27 µs
# Wall time: 31.5 µs
# CPU times: user 33 µs, sys: 11 µs, total: 44 µs
# Wall time: 49.1 µs
# 0.0

# %% [markdown]
# ### Задание 5*

# %% [markdown]
# Нужно написать матричное произведение БЕЗ циклов и БЕЗ символа @, БЕЗ `np.dot` и вообще БЕЗ какой-либо вспомогательной функции из `numpy`, то есть пользуясь только индексированием, взятем суммы по нужным осям и поэлементным произведенем (да, это возможно). Рекомендуем гуглить по запросу "NumPy broadcasting"

# %%
def cool_matrix_product(A, B):
    # Ваш код здесь

# %%
# тут проверьте, что всё правильно перемножается

# %% [markdown]
# Ваш код не будет проверяться нами непосредственно, однако это очень и очень полезное упражнение.

# %% [markdown]
# ## Бонусная часть (в тесте вопросов по ней не будет)

# %% [markdown]
# Image = 2-D численный массив
# (или 3-D: CT, MRI, 2D + time; 4-D, …)
# В текущем задании, image == Numpy array (np.array)

# %%
pic = misc.face()  # встроенная в библиотеку функция, которая загружает картинку с енотом

# %% [markdown]
# Выведите тип и размеры для переменной pic. Что лежит внутри?

# %%
print(type(pic),'\n',pic.shape)
# Out:
# <class 'numpy.ndarray'>
#  (768, 1024, 3)

# %% [markdown]
# Если вы все сделали правильно, что для формы у вас выведется кортеж из трех чисел: (X, Y, 3). Предположите, откуда там 3?
#
# **Ответ:**

# %% [markdown]
# С помощью функции ниже можно вывести изображение и посмотреть, что находится внутри:

# %%
plt.imshow(pic)

# %% [markdown]
# Убедитесь, что внутри массива `pic` действительно лежат числа. Выведите первые 10 записей.
# Массив состоит из троек чисел, которые характеризуют глубину цвета для каждого пикселя. Из пикселей складывается картинка.

# %%
pic.reshape(-1,3)[:10]
# Out:
# array([[121, 112, 131],
#        [138, 129, 148],
#        [153, 144, 165],
#        [155, 146, 167],
#        [155, 146, 167],
#        [158, 148, 172],
#        [159, 149, 173],
#        [156, 146, 170],
#        [147, 138, 159],
#        [137, 128, 149]], dtype=uint8)

# %% [markdown]
# Выведите значение максимального элемента в матрице. Выведите значение минимального. Выведите среднее по всем элементам матрице. В каких пределах лежат значения глубины цветов?

# %%
pic.min(),pic.max(),pic.mean()
# Out:
# (0, 255, 110.16274388631184)

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Теперь загрузим черно-белое изображение енота, чтобы наш массив был не 3-х мерным тензором, а двумерным массивом. Тензоры обрабатываются точно также, но для простоты пока что давайте работать с двумерными массивами, т.е. матрицами.

# %%
pic = misc.face(gray=True)

# %%
plt.imshow(pic)

# %% [markdown]
# Выведите форму (shape) полученной картинки `pic`. Какие выводы можно сделать? Положите в `h`,`w` высоту и ширину картинки.

# %%
print(pic.shape)
h,w=pic.shape[0:2]
# Out:
# (768, 1024)

# %% [markdown]
# Используя библиотеку `numpy`, отразите изображение по горизонтали. Выведите картинку.
#
# Подсказка: не забывайте, что изображения -- это просто двумерные массивы

# %%
#тут ваш код
plt.imshow(pic[:,::-1])

# %% [markdown]
# Теперь давайте повысим контрастность -- для этого к каждому пикселю прибавим 50 единиц

# %%
#тут ваш код
pic = pic + 50

# %%
plt.imshow(pic)

# %% [markdown]
# Теперь давайте попробуем превратить наше одноканальное изображение в трехканальный (RGB) тензор. Для этого вместо каждого пикселя в одноканальном изображении (в двумерном массиве) поставим кортеж из трех элементов -- глубины красного, зеленого и голубого соотвественно. Восстановить по ч/б картинке цветной мы не можем, так как мы не можем взять утерянную информацию из ниоткуда, но можем усилить черные и белые участки. Для этого давайте заполним все три канала одинаковыми значениями, деленными на что-то очень большое. Например $--$ на $200$.  То есть, например, если в пикселе `pic[i][j]` лежало значение **200**, то для нового изображения `new_pic` мы заполняем `new_pic[i][j]` кортежем из трех чисел `int(pic[i][j]/3)`. Функция `int` $--$ округление до целой части.

# %%
new_pic = np.zeros((h,w,3)) #создадим пустую матрицу, куда будем записывать значения
for i in range(h):
    for j in range(w):
        #тут ваш код
        v = int(pic[i][j]/3)
        new_pic[i,j] = (v,v,v)

# %%
plt.imshow(new_pic)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Задание 3

# %% [markdown]
# Теперь давайте уменьшим качество картинки в 16 раз, путем уменьшения качества изображения, т.е. теперь 16 пикселей по близости надо заполнить одним значением.

# %%
from sklearn.datasets import load_sample_image #импорт загрузчика изображения

# %%
china = load_sample_image('china.jpg')
plt.imshow(china)

# %% [markdown]
# Запишите в переменные `h`, `w`, `c` высоту, ширину, количество каналов соответственно для картинки `china`.

# %%
h, w, c = china.shape #тут ваш код

# %% [markdown]
# Теперь давайте непосредственно перейдем к изменению картинки $--$ мы предлагаем разбивать картинки на квадраты 4 на 4 и заполнять все 16 значений внутри квадрата левым верхним значением. Вы можете сделать иначе.

# %%
from copy import copy
compressed_pic = copy(china)
#тут ваш код  
for i in range(compressed_pic.shape[0]):
    for j in range(compressed_pic.shape[1]):
        compressed_pic[i,j] = compressed_pic[i // 4 * 4,j //4 * 4]
        
plt.imshow(compressed_pic)

# %% [markdown]
# Напишите функцию, которая считает несоотвествие между исходной и сжатой картинкой. Запустите ваш код для `compressed_pic`, `china`

# %%
def calculate_mismatch(a,b):
    mismatch=0
    #тут ваш код
    
    mismatch = (a != b).sum()
    
    print(mismatch)

# %%
calculate_mismatch(china,compressed_pic)
# Out:
# 638901

# %% [markdown]
# Посчитайте синус от каждого значения пикселей изображения `china` по всем каналам. Выведите картинку. Используйте функцию `np.sin`

# %%
#тут ваш код
plt.imshow((np.sin(china).astype(int)+1)/2*255)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(#тут ваш код)

# %% [markdown]
# Посмотрите на полученный результат. Как вы думаете, что можно делать с помощью такого преобразования? Какого рода объекты можно распознать?

# %% [markdown]
# ### Задание 4*

# %% [markdown]
# Теперь давайте поработаем с аудиофайлами. Стандартный аудиофайл представляет собой обычный набор чисел, в котором хранятся значения частот, снятых с определенной периодичностью. Итак, самая простая аудиодорожка $-$ одномерный массив.
#
# Первое, что нужно сделать $--$ установить библиотеку для работы с аудио. Она называется `librosa`. Гайд по установке: https://librosa.github.io/librosa/install.html

# %%
import librosa #импортируем библиотеку
import IPython.display

# %%
audio, sr= librosa.load('Test.wav')  
# записываем наш массив звуковых частот в файл аудио, sr -- число точек, записываемых в секунду. 
# чтобы файл открылся, он должен лежать в той же папке, что и файл HW_2.ipynb
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-ca332ad2e33f> in <module>()
# ----> 1 audio, sr= librosa.load('Test.wav')
#       2 # записываем наш массив звуковых частот в файл аудио, sr -- число точек, записываемых в секунду.
#       3 # чтобы файл открылся, он должен лежать в той же папке, что и файл HW_2.ipynb
#
# /usr/local/lib/python3.6/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     117
#     118     y = []
# --> 119     with audioread.audio_open(os.path.realpath(path)) as input_file:
#     120         sr_native = input_file.samplerate
#     121         n_channels = input_file.channels
#
# /usr/local/lib/python3.6/dist-packages/audioread/__init__.py in audio_open(path, backends)
#     109     for BackendClass in backends:
#     110         try:
# --> 111             return BackendClass(path)
#     112         except DecodeError:
#     113             pass
#
# /usr/local/lib/python3.6/dist-packages/audioread/rawread.py in __init__(self, filename)
#      60     """
#      61     def __init__(self, filename):
# ---> 62         self._fh = open(filename, 'rb')
#      63
#      64         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Test.wav'

# %% [markdown]
# Нашу дорожку можно воспроизвести в самом файле `.ipynb`:

# %%
IPython.display.Audio(audio, rate=sr)

# %% [markdown]
# Выведите тип данных переменной `audio`, найдите ее длительность и среднее.

# %%
print(#тут ваш код)

# %% [markdown]
#     Давайте посмотрим, как выглядит наша дорожка. Для этого используем библиотеку `matplotlib.pyplot`

# %%
plt.figure(figsize=(25,5))
plt.title('Test.wav')
plt.plot(audio)

# %% [markdown]
# Обрежьте последние 4 секунды файла

# %%
audio = #тут ваш код

# %% [markdown]
# Давайте уменьшим амплитуду на 25%. Что при этом изменится? Напоминаю, что вы всегда можете послушать изменения при помощи `IPython.display.Audio`

# %%
audio = #тут ваш код

# %% [markdown]
# А еще аудиодорожку можно ускорить. Для этого попробуйте потюнить параметр `rate`

# %%
IPython.display.Audio(audio, rate=sr)
